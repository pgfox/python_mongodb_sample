# %% [markdown]
# <br><br>
#
# # Life Expectancy around the World
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <b>Author</b>: <i>Patrick Fox</i> <br>
# <b>Module</b>: <i>BDL03 1 NoSQL Lab with Python & MongoDB <i><br>
# <b>Date</b>: <i>7 April 2022<i><br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Environment-Configuration" data-toc-modified-id="Environment-Configuration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Environment Configuration</a></span></li><li><span><a href="#Extract-Load-Transform" data-toc-modified-id="Extract-Load-Transform-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Extract Load Transform</a></span><ul class="toc-item"><li><span><a href="#Create-connections-to-MongoDB" data-toc-modified-id="Create-connections-to-MongoDB-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Create connections to MongoDB</a></span></li><li><span><a href="#Remove-all-Existing-Documents" data-toc-modified-id="Remove-all-Existing-Documents-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Remove all Existing Documents</a></span></li><li><span><a href="#Fetch-Data-from-JSON-API's" data-toc-modified-id="Fetch-Data-from-JSON-API's-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Fetch Data from JSON API's</a></span></li><li><span><a href="#Insert-into-MongoDB" data-toc-modified-id="Insert-into-MongoDB-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Insert into MongoDB</a></span></li><li><span><a href="#Transform-Collections" data-toc-modified-id="Transform-Collections-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Transform Collections</a></span><ul class="toc-item"><li><span><a href="#Transform-Country-data" data-toc-modified-id="Transform-Country-data-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Transform Country data</a></span></li><li><span><a href="#Clean-Country-Data" data-toc-modified-id="Clean-Country-Data-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Clean Country Data</a></span></li><li><span><a href="#Transform-Census-Data" data-toc-modified-id="Transform-Census-Data-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Transform Census Data</a></span></li><li><span><a href="#Clean-Census-Data" data-toc-modified-id="Clean-Census-Data-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>Clean Census Data</a></span><ul class="toc-item"><li><span><a href="#Extreme-Life-Expectancy-Values" data-toc-modified-id="Extreme-Life-Expectancy-Values-3.5.4.1"><span class="toc-item-num">3.5.4.1&nbsp;&nbsp;</span>Extreme Life Expectancy Values</a></span></li><li><span><a href="#Validate-Correct-Range-of-Years" data-toc-modified-id="Validate-Correct-Range-of-Years-3.5.4.2"><span class="toc-item-num">3.5.4.2&nbsp;&nbsp;</span>Validate Correct Range of Years</a></span></li></ul></li><li><span><a href="#Create-Combined-Collection" data-toc-modified-id="Create-Combined-Collection-3.5.5"><span class="toc-item-num">3.5.5&nbsp;&nbsp;</span>Create Combined Collection</a></span></li></ul></li></ul></li><li><span><a href="#Analysis" data-toc-modified-id="Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Analysis</a></span><ul class="toc-item"><li><span><a href="#Worldwide-in-2020,-which-countries-have-the-highest-and-lowest-life-expectancy?" data-toc-modified-id="Worldwide-in-2020,-which-countries-have-the-highest-and-lowest-life-expectancy?-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Worldwide in 2020, which countries have the highest and lowest life expectancy?</a></span></li><li><span><a href="#Worldwide-in-2020,-do-females-or-males-have-the-longest-life-expectancy?" data-toc-modified-id="Worldwide-in-2020,-do-females-or-males-have-the-longest-life-expectancy?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Worldwide in 2020, do females or males have the longest life expectancy?</a></span></li><li><span><a href="#In-2020,-how-does--female-and-male-life-expectancy-break-down-per-continent?" data-toc-modified-id="In-2020,-how-does--female-and-male-life-expectancy-break-down-per-continent?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>In 2020, how does  female and male life expectancy break down per continent?</a></span></li><li><span><a href="#In-2020,-which-european-countries-have-the-highest/lowest-life-expectancy?" data-toc-modified-id="In-2020,-which-european-countries-have-the-highest/lowest-life-expectancy?-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>In 2020, which european countries have the highest/lowest life expectancy?</a></span></li><li><span><a href="#In-2020-within-Europe,-where-is-largest-divergence-between-female-and-male-life-expectancy?" data-toc-modified-id="In-2020-within-Europe,-where-is-largest-divergence-between-female-and-male-life-expectancy?-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>In 2020 within Europe, where is largest divergence between female and male life expectancy?</a></span></li><li><span><a href="#Worldwide-from-1950-to-2020,-what-is-the-life-expectancy-trend-per-continent?" data-toc-modified-id="Worldwide-from-1950-to-2020,-what-is-the-life-expectancy-trend-per-continent?-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Worldwide from 1950 to 2020, what is the life expectancy trend per continent?</a></span></li><li><span><a href="#Worldwide-from-1950-to-2020,-which-country-has-the-biggest-change-in-life-expectancy?" data-toc-modified-id="Worldwide-from-1950-to-2020,-which-country-has-the-biggest-change-in-life-expectancy?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Worldwide from 1950 to 2020, which country has the biggest change in life expectancy?</a></span></li><li><span><a href="#In-2020,-is-there-a-correlation-between-a-country's-Gini-Index-and-its-life-expectancy?" data-toc-modified-id="In-2020,-is-there-a-correlation-between-a-country's-Gini-Index-and-its-life-expectancy?-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>In 2020, is there a correlation between a country's Gini Index and its life expectancy?</a></span></li></ul></li><li><span><a href="#Conclusions" data-toc-modified-id="Conclusions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Conclusions</a></span></li><li><span><a href="#Appendix" data-toc-modified-id="Appendix-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Appendix</a></span><ul class="toc-item"><li><span><a href="#Document-formats" data-toc-modified-id="Document-formats-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Document formats</a></span><ul class="toc-item"><li><span><a href="#One-Document-from-the-&quot;raw-countries-collection&quot;" data-toc-modified-id="One-Document-from-the-&quot;raw-countries-collection&quot;-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>One Document from the "raw countries collection"</a></span></li><li><span><a href="#One-Document-from-the-&quot;raw-census-collection&quot;" data-toc-modified-id="One-Document-from-the-&quot;raw-census-collection&quot;-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>One Document from the "raw census collection"</a></span></li><li><span><a href="#One-Document-from-the-&quot;combined--collection&quot;" data-toc-modified-id="One-Document-from-the-&quot;combined--collection&quot;-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>One Document from the "combined  collection"</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Overview
#
# This report focuses on the estimated life expectancy of a country's residents. The analysis focuses on the life expectancy estimates for the year 2020 and the general trend experienced between 1950-2020. The explicit questions addressed and observations are listed in the [Analysis section](#Analysis).
#
#
# This report uses data from the following sources:
#
# * [International Database: World Population Estimates and Projections](https://www.census.gov/programs-surveys/international-programs/about/idb.html). This data is maintained by United States Census Bureau. It consists of population estimates and projections for various demographic measures of over 200 countries and areas of the world with populations of 5,000 or more. The primary data used from this API is the estimated life expectancy.
#
#
# * [restcountries.com](https://restcountries.com/v3.1/all). This is a JSON/Rest API that provides addition information on a country, such as region and geographical area etc.
#
#
# * [data.worldbank.org](https://data.worldbank.org/) is used to make a correction to a small number of individual data points from the Census Bureau data - see [clean census data](#Clean-Census-Data)
#
#
# The report uses an Extract Load Transform approach. The process is summarised as:
# * Extract data from the JSON/API sources
# * Load data into the specific "raw" collection
# * Transform data within MongoDB to the "clean" collection and finally a "combined" collection.
#
# An overview of the Data flow is shown in the graphic below:
# <br>
# <br>
#
# <figure>
# <img src="images/data_flow_2.png"  style="width:100%" align="left">
#
# <figcaption align = "center"><b>Figure 1. Data flow and transformation</b></figcaption>
# </figure>
#
#
# <br>
# <br>
# <br>
# <br>
#
# The final "combined" collection held in MongoDB Atlas has the following structure:
# <br>
# <figure>
# <img src="images/class_diagram_2.png"  style="width:30%" align="center">
#
# <figcaption align = "center"><b>Figure 2. Class Diagram of cleaned/combined data. </b></figcaption>
# </figure>
#
#
# A single document example for both "raw" collections and the "combined" collection can be seen in the [Appendix](#Document-formats)

# %% [markdown]
# ##  Environment Configuration

# %%
# %matplotlib inline
import pymongo
import pprint as pp
import pandas as pd
import requests
import matplotlib.pyplot as plt
import folium
import numpy as np
from scipy.stats import pearsonr

# %% [markdown]
# The versions of packages installed in the python environment used to generate this report:

# %%
#pip3 command 
# !pip3 list | grep "pymongo\|pandas\|pprint\|request\|matplotlib\|folium\|folium\|numpy\|scipy"
# Out:
# folium                            0.12.1.post1
# geopandas                         0.10.2
# matplotlib                        3.5.1
# matplotlib-inline                 0.1.3
# numpy                             1.22.3
# pandas                            1.4.1
# pymongo                           4.0.2
# requests                          2.27.1
# scipy                             1.8.0

# %%
# pandas configuration
pd.set_option('display.precision', 2)
pd.set_option('display.max_rows', 300)
pd.set_option('display.min_rows', 300)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# The following code cell contains helper functions defintions that are used for creating <i>choropleth</i> maps and <i>boxplots</i> throughout the Jupyter Notebook.

# %%
# %%html
# <div class="alert alert-block alert-info">
#
# <b>NOTE</b>: In order to avoid extensive clutter in the generated PDF, the plotting/graphing code cells have
#     been folded away or in some cases hidden. However, all code is
#     available for viewing/running in the accompanying Jupyter Notebook.</div>
# Out:
# <div class="alert alert-block alert-info">
#
# <b>NOTE</b>: In order to avoid extensive clutter in the generated PDF, the plotting/graphing code cells have
#     been folded away or in some cases hidden. However, all code is
#     available for viewing/running in the accompanying Jupyter Notebook.</div>

# %%
# function to create choropleth map 
def create_choropleth_map(data_values,
                          totals_column_name,
                          the_color="green",
                          the_focus=[47, 7.5],
                          the_zoom=3,
                          the_width="100%",
                          the_height="100%"):
    #colour to code mapping
    translate_color = {"green": "YlGn", "red": "PuRd", "orange": "OrRd"}
    #create map
    country_shapes = "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/world-countries.json"
    the_map = folium.Map(location=the_focus, zoom_start=the_zoom, width=the_width, height=the_height)
    folium.Choropleth(geo_data=country_shapes,
                      name='choropleth',
                      data=data_values,
                      columns=['country_code', totals_column_name],
                      key_on='feature.id',
                      fill_color=translate_color[the_color],
                      nan_fill_color='white',
                      fill_opacity=0.6).add_to(the_map)

    #position map
    f = folium.Figure(width=500, height=440)
    f.add_child(the_map)
    return f

# function to create a boxplot plot
def create_sub_boxplot(subplot, data, title, ylabel="",xlabel=""):

    the_labels = ["female", "male"]

    boxp = subplot.boxplot(data,
                           positions=[2, 3],
                           patch_artist=True,
                           vert=True,
                           medianprops={
                               "color": "white",
                               "linewidth": 1.5
                           },
                           boxprops={
                               "facecolor": "#86bf91",
                               "edgecolor": "white",
                               "linewidth": 0.5
                           },
                           whiskerprops={
                               "color": "#86bf91",
                               "linewidth": 1.5
                           },
                           capprops={
                               "color": "#86bf91",
                               "linewidth": 1.5
                           },
                           labels=the_labels)

    subplot.spines["top"].set_visible(False)
    subplot.spines["right"].set_visible(False)
    subplot.set_title(title)
    subplot.grid(axis='y', alpha=0.3)

    subplot.set_ylim([0, 100])
    subplot.set_yticks(np.arange(0, 100, 10), minor=False)
    subplot.set_yticks(np.arange(0, 100, 2), minor=True)
    
    subplot.set_ylabel(ylabel)
    subplot.set_xlabel(xlabel)

    subplot.grid(which='minor', alpha=0.2)
    subplot.grid(which='major', alpha=0.5)

    colors = ["#86bf91", "grey"]

    for box, color in zip(boxp["boxes"], colors):
        box.set_facecolor(color)

# %% [markdown]
# ## Extract Load Transform

# %% [markdown]
# ### Create connections to MongoDB
#
# Define constants used throughout the report.

# %%
# username/password used for accessing the MongoDB Atlas instance.
MONGO_USERNAME = "pfox"
MONGO_PASSWORD = "Project1z3"
MONGO_CXN_STR = (
    f"mongodb+srv://{MONGO_USERNAME}:{MONGO_PASSWORD}@"
    "cluster0.9lwnm.mongodb.net")
    
CENSUS_URL = ("https://api.census.gov/data/timeseries/idb/5year?"
              "get=NAME,POP,E0,E0_F,E0_M,FPOP,MPOP,AREA_KM2"
              "&GENC=*&time=from+1950+to+2020")
COUNTRIES_URL = "https://restcountries.com/v3.1/all"

# MongoDB database name and collection names
DB_NAME = "population_data"
RAW_CENSUS_COLL_NAME = "census_raw"
CLEAN_CENSUS_COLL_NAME = "census_clean"
RAW_COUNTRIES_COLL_NAME = "countries_raw"
CLEAN_COUNTRIES_COLL_NAME = "countries_clean"
COMBINED_COLLECTION = "combined"

# %% [markdown]
# Create a connection to the MongoDB database and collections.

# %%
#create DB connection
client = pymongo.MongoClient(MONGO_CXN_STR)
the_db = client[DB_NAME]

#census data
raw_census_coll = the_db[RAW_CENSUS_COLL_NAME]
clean_census_coll = the_db[CLEAN_CENSUS_COLL_NAME]

# create countries collections
raw_countries_coll = the_db[RAW_COUNTRIES_COLL_NAME]
clean_countries_coll = the_db[CLEAN_COUNTRIES_COLL_NAME]

#combined data
combined_coll = the_db[COMBINED_COLLECTION]

# %% [markdown]
# ### Remove all Existing Documents

# %% [markdown]
# Remove any existing documents from MongoDB Atlas.

# %%
raw_census_coll.drop()
raw_countries_coll.drop()
clean_census_coll.drop()
clean_countries_coll.drop()
combined_coll.drop()

# %% [markdown]
# ###  Fetch Data from JSON API's

# %%
print(f"Fetch data from the Rest API \'{CENSUS_URL.split('?')[0]}\', convert the response into a standard JSON format.")
# Out:
# Fetch data from the Rest API 'https://api.census.gov/data/timeseries/idb/5year', convert the response into a standard JSON format.

# %%
# fetch data from Census API
census_response = requests.get(CENSUS_URL)
census_raw_data = census_response.json()
# have to convert it to the standard data format.
census_raw_df = pd.DataFrame(census_raw_data[1:], columns=census_raw_data[0])
census_raw_json = census_raw_df.to_dict("records")

# %%
print(f"After formatting, the response contains {len(census_raw_json)} documents.")
# Out:
# After formatting, the response contains 16117 documents.

# %%
print(f"Fetch data from the Rest API {COUNTRIES_URL} .")
# Out:
# Fetch data from the Rest API https://restcountries.com/v3.1/all .

# %%
# Fetch data from Countries API
countries_response = requests.get(COUNTRIES_URL)
countries_raw_json = countries_response.json()

# %%
print(f"The formatted JSON contains {len(countries_raw_json)} documents.")
# Out:
# The formatted JSON contains 250 documents.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### Insert into MongoDB

# %% [markdown]
# Load the extracted data from restcountries.com into 'countries_raw' collection and the data from Census Bureau API into the 'census_raw' collection.

# %%
# %%capture
raw_census_coll.insert_many(census_raw_json)
raw_countries_coll.insert_many(countries_raw_json)

# %%
print(f"This inserted {raw_census_coll.count_documents({})} documents into the \'{RAW_CENSUS_COLL_NAME}\' collection and {raw_countries_coll.count_documents({})} documents into the \'{RAW_COUNTRIES_COLL_NAME}\' collection.")
# Out:
# This inserted 16117 documents into the 'census_raw' collection and 250 documents into the 'countries_raw' collection.

# %% [markdown]
# ### Transform Collections

# %% [markdown]
# #### Transform Country data

# %% [markdown]
# Reshape the data in the 'countries_raw' collection and create the 'countries_clean' collection.

# %%
# %%capture
#Transform country data
raw_countries_coll.aggregate([
    {"$project":
         {"_id": 0,
          "cca2": 1,
          "cca3": 1,
          "region": 1,
          "subregion": 1,
          "continents": 1,
          "gini": 1,
          "name": 1
          }
     },
    {"$set": {"_id": "$cca2"}},
    {"$set":
         {"gini_obj":
              {"$first": {"$objectToArray": "$gini"}}
          }
     },
    {"$set": {"gini_value": "$gini_obj.v"}},
    {"$out": CLEAN_COUNTRIES_COLL_NAME}
])

# %%
# %%html
# <div class="alert alert-block alert-info">
#
# The <b>$objectToArray</b> is used above as the <i>key</i> for the actual numeric gini value keeps changing (they
# appear to use a year value for the key). </div>
# Out:
# <div class="alert alert-block alert-info">
#
# The <b>$objectToArray</b> is used above as the <i>key</i> for the actual numeric gini value keeps changing (they
# appear to use a year value for the key). </div>

# %% [markdown]
# #### Clean Country Data

# %% [markdown]
# Validate that each country document in 'countries_clean' has only one continent associated.

# %%
# check country has only one continent
countries_with_more_continents = clean_countries_coll.aggregate([
    {"$match":
          {"$or": 
            [{"continents.0": {"$exists": False}},
             {"continents.1": {"$exists": True}}
            ]
          }       
     }
])
message = (f"There are {len(list(countries_with_more_continents))} countries"
       " with zero continents or more than two continents assigned.")
print(message)
# Out:
# There are 0 countries with zero continents or more than two continents assigned.

# %% [markdown]
# Visually validate the number of countries per continent are approximately correct.

# %%
# group by continent and count number of countries
country_count_per_region = clean_countries_coll.aggregate([
    {"$group": {"_id": {"$arrayElemAt": ["$continents", 0]},
                "number_countries": {"$sum": 1}
               }
    },
    {"$project":
         {"_id": 0,
          "continent": "$_id",
          "number_of_countries": "$number_countries"
          }
     },
    {"$sort": {"number_of_countries": -1}},
    {"$limit": 10}
])
country_count_per_region_df = pd.DataFrame(
    country_count_per_region).set_index("continent")

# %%
#Plot Table 1
country_count_per_region_df.style.set_caption("Table 1: number of countries per continent.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_fc80f caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_fc80f">
#   <caption>Table 1: number of countries per continent.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc80f_level0_col0" class="col_heading level0 col0" >number_of_countries</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >continent</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc80f_level0_row0" class="row_heading level0 row0" >Africa</th>
#       <td id="T_fc80f_row0_col0" class="data row0 col0" >58</td>
#     </tr>
#     <tr>
#       <th id="T_fc80f_level0_row1" class="row_heading level0 row1" >Europe</th>
#       <td id="T_fc80f_row1_col0" class="data row1 col0" >53</td>
#     </tr>
#     <tr>
#       <th id="T_fc80f_level0_row2" class="row_heading level0 row2" >Asia</th>
# ...

# %% [markdown]
# #### Transform Census Data

# %% [markdown]
# Reshape the data contained in 'census_raw' collection and place it in the 'cencus_clean' collection. As part of this transformation step, specific fields that are used in later calculation are converted to decimal types.

# %%
# %%capture
# change to more understandable names. 
raw_census_coll.update_many({}, {"$rename": {
    "E0": "life_expectancy",
    "E0_F": "female_life_expectancy",
    "E0_M": "male_life_expectancy", }})

# reshape data and convert types
raw_census_coll.aggregate([
    #filter out documents that contain a 'Null' life expectancy
    {"$match": {"life_expectancy": {"$ne": None}}},
    {"$addFields": {
        "year": {"$toInt": "$time"},
        "life_expectancy_dec": {"$toDecimal": "$life_expectancy"},
        "female_life_expectancy_dec": {"$toDecimal": "$female_life_expectancy"},
        "male_life_expectancy_dec": {"$toDecimal": "$male_life_expectancy"},
        "population": {"$toInt": "$POP"},
    }},
    #remove unneeded fields
    {"$project": {
        "life_expectancy": 0,
        "female_life_expectancy": 0,
        "male_life_expectancy": 0,
        "time": 0
    }},
    #rename fields in cleaned data
    {"$project": {
        "country_2_code": "$GENC",
        "area_km2": "$AREA_KM2",
        "name": "$NAME",
        "population": 1,
        "life_expectancy_dec": 1,
        "female_life_expectancy_dec": 1,
        "male_life_expectancy_dec": 1,
        "year": 1
    }},
    {"$out": CLEAN_CENSUS_COLL_NAME}
])

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
# #### Clean Census Data

# %% [markdown]
# ##### Extreme Life Expectancy Values
#
# Search for any values that are very extreme - they would suggest data may not be correct.

# %%
#to do check for outliers in values for expected life expectancy
census_value_check = clean_census_coll.aggregate([
    {"$match":
        {"$or": [
            {"life_expectancy_dec": {"$not": {"$gte": 15, "$lt": 95}}},
            {"female_life_expectancy_dec": {"$not": {"$gte": 15, "$lt": 95}}},
            {"male_life_expectancy_dec": {"$not": {"$gte": 15, "$lt": 95}}},
        ]}},
    {"$project": {
        "_id": 0,
        "year": "$year",
        "name": "$name",
        "life_expectancy": "$life_expectancy_dec",
        "female_life_expectancy": "$female_life_expectancy_dec",
        "male_life_expectancy": "$male_life_expectancy_dec"
    }}
])

# %%
#Table 2
extreme_life_expectancy_df = pd.DataFrame(census_value_check) 
extreme_life_expectancy_df.style.set_caption("Table 2: Countries with extreme values for life expectancy").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_fdce8 caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_fdce8">
#   <caption>Table 2: Countries with extreme values for life expectancy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdce8_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_fdce8_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_fdce8_level0_col2" class="col_heading level0 col2" >life_expectancy</th>
#       <th id="T_fdce8_level0_col3" class="col_heading level0 col3" >female_life_expectancy</th>
#       <th id="T_fdce8_level0_col4" class="col_heading level0 col4" >male_life_expectancy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdce8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fdce8_row0_col0" class="data row0 col0" >1975</td>
#       <td id="T_fdce8_row0_col1" class="data row0 col1" >Cambodia</td>
# ...

# %% [markdown]
# The numbers for Rwanda seem extremely small for 1994 - we will look at Cambodia in [section 4.6](#Worldwide-from-1950-to-2020,-which-country-has-the-biggest-change-in-life-expectancy?).
#
# Extracted below is the life expectancy for Rwanda in the years surrounding 1994.

# %%
#search for rwanda during the 1990 - 1999
rwanda_query_1990_1999 = [
    {"$match": {"name": "Rwanda",
                "year": {"$in": list(range(1990, 2000))}
                }},
    {"$project": {"_id": 0,
                  "year": "$year",
                  "name": "$name",
                  "life_expectancy": "$life_expectancy_dec",
                  "female_life_expectancy": "$female_life_expectancy_dec",
                  "male_life_expectancy": "$female_life_expectancy_dec"
                  }
     },
    {"$sort": {"year": 1}},
    {"$limit": 12}
]
rwanda_1990_1999 = clean_census_coll.aggregate(rwanda_query_1990_1999)

# %%
#Table 3 
rwanda_1990_1999_df = pd.DataFrame(rwanda_1990_1999)
rwanda_1990_1999_df.style.set_caption("Table 3: Rwanda's life expectancy in the nineties.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_c0fc8 caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_c0fc8">
#   <caption>Table 3: Rwanda's life expectancy in the nineties.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0fc8_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_c0fc8_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_c0fc8_level0_col2" class="col_heading level0 col2" >life_expectancy</th>
#       <th id="T_c0fc8_level0_col3" class="col_heading level0 col3" >female_life_expectancy</th>
#       <th id="T_c0fc8_level0_col4" class="col_heading level0 col4" >male_life_expectancy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0fc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0fc8_row0_col0" class="data row0 col0" >1990</td>
#       <td id="T_c0fc8_row0_col1" class="data row0 col1" >Rwanda</td>
# ...

# %% [markdown]
# Data from the [World Bank](https://data.worldbank.org/indicator/SP.DYN.LE00.IN?locations=RW) (for Rwanda during this timeperiod) shows that there was a dramatic drop in life expectancy. But this decrease in life expectancy occurred over approx 10 years and the lowest value for life expectancy is age 26. I decided to update the Census data for Rwanda ,for this specific time period, using the data from the World Bank - see below.
#
# The data is fetched from the World Bank API and updated in the census_clean collection.

# %%
RWANDA_WORLD_BANK=("https://api.worldbank.org/v2/country/"
                   "rwa/indicator/SP.DYN.LE00.IN"
                   ";SP.DYN.LE00.FE.IN;SP.DYN.LE00.MA.IN?"
                   "format=json&date=1987:2000&source=2")
#retrieve json response from API and convert to DataFrame
rwanda_response = requests.get(RWANDA_WORLD_BANK)
rwanda_json = rwanda_response.json()
rwanda_df = pd.json_normalize(rwanda_json[1]) 

for the_year in range(1990,2000):
    #retrieve the values from json response
    life_expectancy_wbank = rwanda_df.loc[
        ((rwanda_df["indicator.id"]=="SP.DYN.LE00.IN") & 
           (rwanda_df["date"]==str(the_year))),"value"].item()
    female_life_expectancy_wbank = rwanda_df.loc[
        ((rwanda_df["indicator.id"]=="SP.DYN.LE00.FE.IN") &
           (rwanda_df["date"]==str(the_year))),"value"].item()
    male_life_expectancy_wbank = rwanda_df.loc[(
        (rwanda_df["indicator.id"]=="SP.DYN.LE00.MA.IN") & 
          (rwanda_df["date"]==str(the_year))),"value"].item()
    
    # update each year
    clean_census_coll.update_one(
        {"name": "Rwanda", "year": the_year},
        {"$set": 
           {"life_expectancy_dec": float(life_expectancy_wbank),
            "female_life_expectancy_dec": float(female_life_expectancy_wbank),
            "male_life_expectancy_dec": float(male_life_expectancy_wbank)
            }
        }
    )

# %% [markdown]
#  Rerun the query against MongoDB to ensure the update was successful.

# %%
rwanda_years_corrected = clean_census_coll.aggregate(rwanda_query_1990_1999)

# %%
#display table 4
rwanda_years_corrected_df = pd.DataFrame(rwanda_years_corrected)
rwanda_years_corrected_df.style.set_caption("Table 4: AFTER CORRECTION Rwanda's life expectancy in the nineties.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_b5dcd caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_b5dcd">
#   <caption>Table 4: AFTER CORRECTION Rwanda's life expectancy in the nineties.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5dcd_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_b5dcd_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_b5dcd_level0_col2" class="col_heading level0 col2" >life_expectancy</th>
#       <th id="T_b5dcd_level0_col3" class="col_heading level0 col3" >female_life_expectancy</th>
#       <th id="T_b5dcd_level0_col4" class="col_heading level0 col4" >male_life_expectancy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5dcd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5dcd_row0_col0" class="data row0 col0" >1990</td>
# ...

# %% [markdown]
# ##### Validate Correct Range of Years
#
# Check to ensure the correct range of years are returned from the Census Bureau API.

# %%
# check the year value is in the expected range
census_value_check = clean_census_coll.aggregate([
    {"$match": {"year": {"$not": {"$gte": 1950, "$lte": 2020}}},
     }
])
message=(f"There are {len(list(census_value_check))} countries "
         "with years outside the expected range (1950 - 2020).")
print(message)
# Out:
# There are 0 countries with years outside the expected range (1950 - 2020).

# %% [markdown]
# #### Create Combined Collection
#
# A 'combined' collection is created using the 'census_clean' collection and the 'countries_clean' collection.
#
# The 'census_clean' data is the primary data and the 'countries_clean' data is used to supplement.

# %%
#create parent-child documents and write out as combined collection
clean_census_coll.aggregate([
    #group by country
    {"$group": {"_id": "$name", 
                "area_km2": {"$last": "$area_km2"},
                "country_2_code": {"$last": "$country_2_code"}
               }
    },
    {"$addFields": {"area_km2_int": {"$toInt": "$area_km2"}}},
    {"$addFields": {"name": "$_id"}},
    #add orginal documents as children to new group
    {"$lookup":
         {"from": CLEAN_CENSUS_COLL_NAME,
          "localField": "name",
          "foreignField": "name",
          "as": "yearly_data"}},
    #add country details as a child document
    {"$lookup":
         {"from": CLEAN_COUNTRIES_COLL_NAME,
          "localField": "country_2_code",
          "foreignField": "_id",
          "as": "country_data"}},
    #flatten country child document into parent document
    {"$unwind": "$country_data"},
    {"$addFields": {"continent":
                        {"$arrayElemAt": ["$country_data.continents", 0]}}},
    {"$project": {"_id": "$country_2_code",
                  "name": "$name",
                  "country_code": "$country_data.cca3",
                  "area_km2_int": 1,
                  "region": "$country_data.region",
                  "subregion": "$country_data.subregion",
                  "gini_value": "$country_data.gini_value",
                  "yearly_data": 1,
                  "continent": 1,

                  }
     },
    {"$out": COMBINED_COLLECTION}])

#read in from mongodb, to confirm number of documents inserted 
country_list = combined_coll.aggregate([
    {"$project": { "_id":0,"country": "$name"}}
])
message=(f"The 'combined' collection contains {len(list(country_list))} "
         "country documents in total.")
print(message)
# Out:
# The 'combined' collection contains 225 country documents in total.

# %% [markdown]
# Many countries do not have estimates of Life Expectancy attached for every year during the timeperiod 1950 - 2020. Many countries appeared to only have estimates for the later years. <b>Figure 3</b> (below) shows how many countries have estimates attached for each year.

# %%
# find number of life expectancy records/docs per year
expected_life_records_by_year = combined_coll.aggregate([
    {"$unwind": "$yearly_data"},
    {"$group": {"_id": "$yearly_data.year", "number_yearly_docs": {"$sum": 1}}},
    {"$set": {"year": "$_id"}},
    {"$project": {"_id": 0}},
    {"$sort": {"year": 1}},
    {"$limit": 100}
])
records_by_year_df = pd.DataFrame(expected_life_records_by_year)

# %%
#Plot the number of yearly docs
#Figure 3
fig, ax = plt.subplots()
fig.set_size_inches(10,8)
ax.barh(records_by_year_df["year"],records_by_year_df["number_yearly_docs"], height=0.65, color="#86bf91")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_xlabel("number of countries with an estimate")
ax.set_ylabel("year")
plt.grid(axis='x', alpha=0.3)
txt="Figure 3: How many countries have a Life Expectancy estimate recorded for that specific year."
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10)
plt.show()

# %% [markdown]
# Show the top 5 countries with the most estimates attached.

# %%
# how many yearly documents each country has attached
amount_yearly_data = combined_coll.aggregate([
    {"$project": {"_id": 0, 
                  "country": "$name", 
                  "number_yearly_estimates": {"$size": "$yearly_data"}
                 }
    },
    {"$sort": {"number_yearly_estimates": -1}}])

amount_yearly_data_df = pd.DataFrame(amount_yearly_data)

# %%
#display Table 5 
amount_yearly_data_df = amount_yearly_data_df.set_index("country")
amount_yearly_data_df.head().style.set_caption("Table 5: Countries with most yearly estimates.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_37325 caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_37325">
#   <caption>Table 5: Countries with most yearly estimates.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37325_level0_col0" class="col_heading level0 col0" >number_yearly_estimates</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37325_level0_row0" class="row_heading level0 row0" >Bhutan</th>
#       <td id="T_37325_row0_col0" class="data row0 col0" >71</td>
#     </tr>
#     <tr>
#       <th id="T_37325_level0_row1" class="row_heading level0 row1" >Djibouti</th>
#       <td id="T_37325_row1_col0" class="data row1 col0" >71</td>
#     </tr>
#     <tr>
#       <th id="T_37325_level0_row2" class="row_heading level0 row2" >Nigeria</th>
# ...

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Worldwide in 2020, which countries have the highest and lowest life expectancy?

# %% [markdown]
# Fetch the life expectancy per country for the year 2020.

# %%
life_expt_2020 = combined_coll.aggregate([
    {"$unwind": "$yearly_data"},
    {"$match": {"yearly_data.year": 2020}},
    {"$sort": {"yearly_data.life_expectancy_dec": -1}},
    {"$project": 
       {"_id": 0,
        "country": "$name",
        "country_code": 1,
        "area_km2": "$area_km2_int",
        "gini_value": 1,
        "country_population": "$yearly_data.population",
        "life_expectancy": "$yearly_data.life_expectancy_dec",
        "female_life_expectancy": "$yearly_data.female_life_expectancy_dec",
        "male_life_expectancy": "$yearly_data.male_life_expectancy_dec"
        }
     },
    {"$limit": 300}
])

life_expt_2020_df = pd.DataFrame(life_expt_2020)
# convert from type Decimal to float (needed for plotting)
life_expt_2020_df["life_expectancy"] = life_expt_2020_df[
    "life_expectancy"].astype(str).astype(float)
life_expt_2020_df["male_life_expectancy"] = life_expt_2020_df[
    "male_life_expectancy"].astype(str).astype(float)
life_expt_2020_df["female_life_expectancy"] = life_expt_2020_df[
    "female_life_expectancy"].astype(str).astype(float)

# %%
#display Table 6 
life_expt_2020_df[
    ["country","life_expectancy","area_km2","country_population"]
].set_index('country').head().style.set_caption(
    "Table 6: The 5 countries world wide with highest life expectancy in 2020.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_70f8c caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_70f8c">
#   <caption>Table 6: The 5 countries world wide with highest life expectancy in 2020.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70f8c_level0_col0" class="col_heading level0 col0" >life_expectancy</th>
#       <th id="T_70f8c_level0_col1" class="col_heading level0 col1" >area_km2</th>
#       <th id="T_70f8c_level0_col2" class="col_heading level0 col2" >country_population</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70f8c_level0_row0" class="row_heading level0 row0" >Monaco</th>
#       <td id="T_70f8c_row0_col0" class="data row0 col0" >89.270000</td>
# ...

# %%
#display Table 7 
life_expt_2020_df[
    ["country","life_expectancy","area_km2","country_population"]
].set_index('country').tail(5).style.set_caption(
    ("Table 7: The 5 countries worldwide"
     " with lowest life expectancy in 2020.")).set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_7b35a caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_7b35a">
#   <caption>Table 7: The 5 countries worldwide with lowest life expectancy in 2020.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b35a_level0_col0" class="col_heading level0 col0" >life_expectancy</th>
#       <th id="T_7b35a_level0_col1" class="col_heading level0 col1" >area_km2</th>
#       <th id="T_7b35a_level0_col2" class="col_heading level0 col2" >country_population</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b35a_level0_row0" class="row_heading level0 row0" >Mozambique</th>
#       <td id="T_7b35a_row0_col0" class="data row0 col0" >55.870000</td>
# ...

# %% [markdown]
# Plot the average life expectancy on a choropleth map. The darker green signifies the longer life expectancy.

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observation</b>:
#      <li> Monaco has the highest life expectancy (age 89).</li>
#      <li> Afghanistan has the lowest life expectancy (age 52) - (at least from the Census Bureau data).</li>
#      <li> From the map (below) it appears that life expectancy is generally high in Europe, North America and parts of Asia.
#     </li>
#     <li> From the map (below) it seems that central region of Africa has a lower life expectancy.
#     </li>
# </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observation</b>:
#      <li> Monaco has the highest life expectancy (age 89).</li>
#      <li> Afghanistan has the lowest life expectancy (age 52) - (at least from the Census Bureau data).</li>
#      <li> From the map (below) it appears that life expectancy is generally high in Europe, North America and parts of Asia.
#     </li>
#     <li> From the map (below) it seems that central region of Africa has a lower life expectancy.
#     </li>
# </div>

# %%
#plot map - Figure 4
create_choropleth_map(life_expt_2020_df,"life_expectancy"
                      ,the_focus=[37,15],the_zoom=1.2)
# Out:
# <iframe src="about:blank" width="500" height="440"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20sr
# ...

# %% [markdown]
# ### Worldwide in 2020, do females or males have the longest life expectancy?
#
# Using the life expectancy reported per country (worldwide) in 2020; compare the median female life expectancy against the median male life expectancy.

# %%
#Plot Figure 5
fig, ax = plt.subplots()

create_sub_boxplot(subplot=ax, 
                   data=life_expt_2020_df[["female_life_expectancy","male_life_expectancy"]],
                   title="World Wide")

ax.set_xlabel("gender")
ax.set_ylabel("life expectancy(age)")
txt="Figure 5: 2020 worldwide, Boxplot of Life Expectancy reported by country."
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10)
fig.set_size_inches(10,8)
plt.show()

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li> It seems the median female life expectancy reported from countries world wide is approx 78 years while male is approx 73 years
#     </li>
#     <li> The distribution of both females and males life expectancy(per country worldwide) seems reasonably
#     semetric (with a few lower outliers)
#     </li>
#
# </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li> It seems the median female life expectancy reported from countries world wide is approx 78 years while male is approx 73 years
#     </li>
#     <li> The distribution of both females and males life expectancy(per country worldwide) seems reasonably
#     semetric (with a few lower outliers)
#     </li>
#
# </div>

# %% [markdown]
# <br><br><br><br><br><br>

# %% [markdown]
# ### In 2020, how does  female and male life expectancy break down per continent?
#
# Group the countries by continent and average the countries life expectancy.

# %%
# %%html
# <div class="alert alert-block alert-info">
# In the grouping below, all the actual female and male life expectancy values per country are retained in the lists <b>female_life_expectancy_list</b> and <b>male_life_expectancy_list</b>. These where used in the subsequent boxplots in Figure 4
#
# </div>
# Out:
# <div class="alert alert-block alert-info">
# In the grouping below, all the actual female and male life expectancy values per country are retained in the lists <b>female_life_expectancy_list</b> and <b>male_life_expectancy_list</b>. These where used in the subsequent boxplots in Figure 4
#
# </div>

# %%
# group by continent 
group_by_continent_2020 = combined_coll.aggregate([
    #flatten out
    {"$unwind": "$yearly_data"},
    #match only 2020
    {"$match": {"yearly_data.year": 2020}},
    #group by continent
    {"$group": 
      {"_id": "$continent",
       "area_km2": {"$sum": "$area_km2_int"},
       "life_expectancy": {"$avg": "$yearly_data.life_expectancy_dec"},
       "female_life_expectancy":
           {"$avg": "$yearly_data.female_life_expectancy_dec"},
        "male_life_expectancy": 
             {"$avg": "$yearly_data.male_life_expectancy_dec"},
        #retain original values - used by boxplot
        "female_life_expectancy_list": 
             {"$push": "$yearly_data.female_life_expectancy_dec"},
        "male_life_expectancy_list": 
             {"$push": "$yearly_data.male_life_expectancy_dec"},
        "number_of_countries": {"$sum": 1},
        }
     },
    {"$project": 
     {"_id": 0,
      "continent": "$_id",
      "area_km2(millions)": {"$round": [{"$divide": ["$area_km2", 1000000]}, 2]},
      "avg_life_expectancy": {"$round": ["$life_expectancy", 2]},
      "female_life_expectancy": {"$round": ["$female_life_expectancy", 2]},
      "male_life_expectancy": {"$round": ["$male_life_expectancy", 2]},
      "female_life_expectancy_list": 1,
      "male_life_expectancy_list": 1,
      "number_of_countries": 1
        }
     },
    {"$sort": {"avg_life_expectancy": -1}},
    {"$limit": 10}
])
group_by_continent_2020_df = pd.DataFrame(group_by_continent_2020)

# %%
#display Table 8. 
display_df = group_by_continent_2020_df[["continent","avg_life_expectancy","number_of_countries","area_km2(millions)"]].set_index("continent")
display_df.style.set_caption(
    "Table 8: Average country life expectancy per continent in 2020.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_04ffe caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_04ffe">
#   <caption>Table 8: Average country life expectancy per continent in 2020.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04ffe_level0_col0" class="col_heading level0 col0" >avg_life_expectancy</th>
#       <th id="T_04ffe_level0_col1" class="col_heading level0 col1" >number_of_countries</th>
#       <th id="T_04ffe_level0_col2" class="col_heading level0 col2" >area_km2(millions)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >continent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04ffe_level0_row0" class="row_heading level0 row0" >Europe</th>
#       <td id="T_04ffe_row0_col0" class="data row0 col0" >79.48</td>
# ...

# %% [markdown]
# Create a boxplot subplot for each continent, that shows the median male and female life expectancy for each country.

# %%
#plot boxplots per continent Figure 6
def convert_decimal_list( the_dataframe,column, continent):
    decimal_list = the_dataframe.loc[the_dataframe["continent"] == continent ,column].tolist()
    float_list = [float(str(x)) for x in decimal_list[0]]
    return float_list

fig, ax = plt.subplots( nrows=1, ncols=6, sharey=True)

plot_data_europe = pd.DataFrame({"female" : convert_decimal_list(group_by_continent_2020_df,"female_life_expectancy_list","Europe"),
                                 "male": convert_decimal_list(group_by_continent_2020_df,"male_life_expectancy_list","Europe")})
create_sub_boxplot(subplot=ax[0], data=plot_data_europe, title="Europe",ylabel="life expectancy(age)")

plot_data_north_america = pd.DataFrame({"female" : convert_decimal_list(group_by_continent_2020_df,"female_life_expectancy_list","North America"),
                                 "male": convert_decimal_list(group_by_continent_2020_df,"male_life_expectancy_list","North America")})
create_sub_boxplot(subplot=ax[1], data=plot_data_north_america, title="North America")

plot_data_asia = pd.DataFrame({"female" : convert_decimal_list(group_by_continent_2020_df,"female_life_expectancy_list","Asia"),
                                 "male": convert_decimal_list(group_by_continent_2020_df,"male_life_expectancy_list","Asia")})
create_sub_boxplot(subplot=ax[2], data=plot_data_asia, title="Asia")

plot_data_south_america = pd.DataFrame(
    {"female" : convert_decimal_list(group_by_continent_2020_df,"female_life_expectancy_list","South America"),
     "male": convert_decimal_list(group_by_continent_2020_df,"male_life_expectancy_list","South America")
    })
create_sub_boxplot(subplot=ax[3], data=plot_data_south_america, title="South America")

plot_data_oceania = pd.DataFrame({"female" : convert_decimal_list(group_by_continent_2020_df,"female_life_expectancy_list","Oceania"),
                                 "male": convert_decimal_list(group_by_continent_2020_df,"male_life_expectancy_list","Oceania")})
create_sub_boxplot(subplot=ax[4], data=plot_data_oceania, title="Oceania")

plot_data_africa = pd.DataFrame({"female" : convert_decimal_list(group_by_continent_2020_df,"female_life_expectancy_list","Africa"),
                                 "male": convert_decimal_list(group_by_continent_2020_df,"male_life_expectancy_list","Africa")})
create_sub_boxplot(subplot=ax[5], data=plot_data_africa, title="Africa")

txt="Figure 4. Boxplot of life expectancy reported by country, grouped by continent."
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10)
plt.grid(axis='y', alpha=0.3)

fig.set_size_inches(16,8)

plt.show()

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>In all continents it seems the median for life expectancy per country is consisently higher for females than males.
#     </li>
#     <li>Europe seems to have the highest medians for both female and male.
#     </li>
#     <li>Africa has the lowest medians and the widest distributions of life expectancies of any of the continents.
#     </li>
#
# </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>In all continents it seems the median for life expectancy per country is consisently higher for females than males.
#     </li>
#     <li>Europe seems to have the highest medians for both female and male.
#     </li>
#     <li>Africa has the lowest medians and the widest distributions of life expectancies of any of the continents.
#     </li>
#
# </div>

# %% [markdown]
# <br><br><br>
# ### In 2020, which european countries have the highest/lowest life expectancy?

# %%
europe_diff = combined_coll.aggregate([
    {"$unwind": "$yearly_data"},
    {"$match": {"yearly_data.year": 2020}},
    {"$match": {"continent": "Europe"}},
    {"$project": 
     {"_id": 0,
      "country": "$name",
      "country_code": 1,
      "life_expectancy": {"$round": ["$yearly_data.life_expectancy_dec", 2]},
      "female_life_expectancy": 
          {"$round": ["$yearly_data.female_life_expectancy_dec", 2]},
      "male_life_expectancy": 
          {"$round": ["$yearly_data.male_life_expectancy_dec", 2]},
      "female_male_difference": 
          {"$round": 
           [{ "$subtract":
              ["$yearly_data.female_life_expectancy_dec",
               "$yearly_data.male_life_expectancy_dec"]
            }, 2]
          },
        }
     },
    {"$sort": {"life_expectancy": -1}},
    {"$limit": 100}])

europe_df = pd.DataFrame(europe_diff)
europe_df["life_expectancy"] = europe_df["life_expectancy"].astype(str).astype(float)
europe_df["female_male_difference"] = europe_df[
    "female_male_difference"].astype(str).astype(float)

# %%
#display Table 9 
display_df = europe_df[["country","life_expectancy"]]
display_df.head(6).style.set_caption(
    "Table 9: The top 6 countries in Europe by life expectancy in 2020.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_0a054 caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_0a054">
#   <caption>Table 9: The top 6 countries in Europe by life expectancy in 2020.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a054_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_0a054_level0_col1" class="col_heading level0 col1" >life_expectancy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a054_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a054_row0_col0" class="data row0 col0" >Monaco</td>
#       <td id="T_0a054_row0_col1" class="data row0 col1" >89.270000</td>
#     </tr>
#     <tr>
#       <th id="T_0a054_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a054_row1_col0" class="data row1 col0" >San Marino</td>
#       <td id="T_0a054_row1_col1" class="data row1 col1" >83.490000</td>
#     </tr>
# ...

# %%
#Table 10
display_df.tail(6).style.set_caption(
    "Table 10: The lowest 6 countries in Europe by life expectancy in 2020.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_96dfb caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_96dfb">
#   <caption>Table 10: The lowest 6 countries in Europe by life expectancy in 2020.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96dfb_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_96dfb_level0_col1" class="col_heading level0 col1" >life_expectancy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96dfb_level0_row0" class="row_heading level0 row0" >44</th>
#       <td id="T_96dfb_row0_col0" class="data row0 col0" >Serbia</td>
#       <td id="T_96dfb_row0_col1" class="data row0 col1" >73.890000</td>
#     </tr>
#     <tr>
#       <th id="T_96dfb_level0_row1" class="row_heading level0 row1" >45</th>
#       <td id="T_96dfb_row1_col0" class="data row1 col0" >Belarus</td>
#       <td id="T_96dfb_row1_col1" class="data row1 col1" >73.740000</td>
#     </tr>
# ...

# %% [markdown]
# Map life expectency on the map of Europe for 2020. Darker green shows longer life expectancy - legend in years.

# %%
#Figure 7
create_choropleth_map(europe_df,"life_expectancy",the_focus=[65,30],the_zoom=2.0)
# Out:
# <iframe src="about:blank" width="500" height="440"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20sr
# ...

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>Monaco, although small, has the highest life expectancy in Europe.</li>
#     <li>Kosovo has the lowest life expectancy in Europe.</li>
#     <li>Life expectancy seems lowest in the east of Europe. It appears
#     to increase in the west and north of Europe</li>
# </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>Monaco, although small, has the highest life expectancy in Europe.</li>
#     <li>Kosovo has the lowest life expectancy in Europe.</li>
#     <li>Life expectancy seems lowest in the east of Europe. It appears
#     to increase in the west and north of Europe</li>
# </div>

# %% [markdown]
# ### In 2020 within Europe, where is largest divergence between female and male life expectancy?

# %%
#display Table 11.
#reuse existing dataframe - as data is already in dataframe 
display_df = europe_df[["country","female_male_difference"]]
#sorting in pandas this time (as we have needed data already from mongodb)
display_df = display_df.sort_values("female_male_difference",ascending=False).set_index("country")
display_df.head(5).style.set_caption(
    "Table 11: The top 6 countries, with greatest difference between male and female life expectancy (ascending order).").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_c843b caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_c843b">
#   <caption>Table 11: The top 6 countries, with greatest difference between male and female life expectancy (ascending order).</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c843b_level0_col0" class="col_heading level0 col0" >female_male_difference</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c843b_level0_row0" class="row_heading level0 row0" >Russia</th>
#       <td id="T_c843b_row0_col0" class="data row0 col0" >11.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c843b_level0_row1" class="row_heading level0 row1" >Belarus</th>
#       <td id="T_c843b_row1_col0" class="data row1 col0" >11.200000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# The following map shows how much longer a female is expected to live compared to a male, within the countries of Europe. The darker the maroon colour, the longer a females lives compared to a male (legend in years).

# %%
#Figure 8
create_choropleth_map(europe_df,"female_male_difference",the_color="red",the_focus=[65,30],the_zoom=2.0)
# Out:
# <iframe src="about:blank" width="500" height="440"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20sr
# ...

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>Russia has the largest divergence in life expectancy in Europe - females are expected to live 11.5 years longer.</i>
#     <li>It seems that in the east of Europe, females live quite a lot longer than males. </li>
#     <li>In the centre and north of Europe, females still live longer, but the difference in life expectancy is not as large.</i>
# </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>Russia has the largest divergence in life expectancy in Europe - females are expected to live 11.5 years longer.</i>
#     <li>It seems that in the east of Europe, females live quite a lot longer than males. </li>
#     <li>In the centre and north of Europe, females still live longer, but the difference in life expectancy is not as large.</i>
# </div>

# %% [markdown]
# <br><br>
# ### Worldwide from 1950 to 2020, what is the life expectancy trend per continent?

# %% [markdown]
# Below life expectancy is grouped by continents and plotted against time.
# As showned in [Create Combined Collection](#Create-Combined-Collection); not all countries have life expectancy records for each year.

# %%
# average per year per continent
average_by_year = combined_coll.aggregate([
    {"$unwind": "$yearly_data"},
    {"$group":
         {"_id":
              {"year": "$yearly_data.year",
               "continent": "$continent"
               },
          "avg_life_expectancy":
              {"$avg": "$yearly_data.life_expectancy_dec"}
          }
     },
    {"$project":
         {"_id": 0,
          "year": "$_id.year",
          "continent": "$_id.continent",
          "avg_life_expectancy":
              {"$round": ["$avg_life_expectancy", 2]}
          }
     },
    {"$sort": {"year": 1}},
    {"$limit": 800}
])

plotting_df = pd.DataFrame(average_by_year)

# %%
#plot continents line graph "trend" - Figure 9
plotting_df["avg_life_expectancy"] = plotting_df["avg_life_expectancy"].astype(
    str).astype(float)

fig, ax = plt.subplots()

ax.plot(plotting_df.loc[plotting_df["continent"] == "Europe", "year"],
         plotting_df.loc[plotting_df["continent"] == "Europe",
                         "avg_life_expectancy"],
         label="Europe",
         linestyle="dashdot",
         linewidth=2)
ax.plot(plotting_df.loc[plotting_df["continent"] == "North America", "year"],
         plotting_df.loc[plotting_df["continent"] == "North America",
                         "avg_life_expectancy"],
         label="North America",
         linestyle="dashdot",
         linewidth=2)
ax.plot(plotting_df.loc[plotting_df["continent"] == "Asia", "year"],
         plotting_df.loc[plotting_df["continent"] == "Asia",
                         "avg_life_expectancy"],
         label="asia",
         linestyle="dashdot",
         linewidth=2)
ax.plot(plotting_df.loc[plotting_df["continent"] == "Oceania", "year"],
         plotting_df.loc[plotting_df["continent"] == "Oceania",
                         "avg_life_expectancy"],
         label="Oceania",
         linestyle="dashdot",
         linewidth=2)
ax.plot(plotting_df.loc[plotting_df["continent"] == "Africa", "year"],
         plotting_df.loc[plotting_df["continent"] == "Africa",
                         "avg_life_expectancy"], label="Africa",linestyle="dashdot",linewidth=2)
ax.set_xlabel("year")
ax.set_ylabel("age")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

txt="Figure 9. average life expectancy of countries world wide, grouped by continent and plotted against time."
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10)
plt.grid(axis='y', alpha=0.3)
plt.grid(axis='x', alpha=0.3)

fig.set_size_inches(16, 6)
plt.xticks(rotation=90)

plt.legend()
plt.show()

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>All continents are experiencing a general upward trend.</li>
#     <li>Europe have consistently had a higher average of country life expectancy for the
#     last four decades (for all the data points we have in our dataset)</i>
# </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>All continents are experiencing a general upward trend.</li>
#     <li>Europe have consistently had a higher average of country life expectancy for the
#     last four decades (for all the data points we have in our dataset)</i>
# </div>

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# ### Worldwide from 1950 to 2020, which country has the biggest change in life expectancy?
#
# Find the biggest difference in life expectancy listed for each country.

# %%
# country with greatest change in life expectancy
change_in_life_expectancy = combined_coll.aggregate([
    {"$addFields": {"number_years_recorded": {"$size": "$yearly_data"}}},
    {"$unwind": {"path": "$yearly_data"}},
    #group by country - finding max and min life expectancy
    {"$group": 
     {"_id": "$name",
      "country_code": {"$last": "$country_code"},
      "number_years_recorded": {"$last": "$number_years_recorded"},
      "max_life_expectancy": {"$max": "$yearly_data.life_expectancy_dec"},
      "min_life_expectancy": {"$min": "$yearly_data.life_expectancy_dec"}
      }
     },
    #calculate life expectancy change per country
    {"$project": 
     {"_id": 0,
      "country": "$_id",
      "country_code": 1,
      "number_years_recorded": 1,
      "max_life_expectancy": 1,
      "min_life_expectancy": 1,
      "change_in_life_expectancy": 
          {"$subtract": ["$max_life_expectancy", "$min_life_expectancy"]}
      }
     },
    {"$sort": {"change_in_life_expectancy": -1}},
    {"$limit": 300}
])
change_df = pd.DataFrame(change_in_life_expectancy)
change_df["change_in_life_expectancy"] = change_df[
    "change_in_life_expectancy"].astype(str).astype(float)

# %% [markdown]
# Map shows how much life expectancy worldwide has changed between 1950 and 2020 (based on the data we have). The darker red signifies a larger change in life expectancy (legend is in years).

# %%
#plot the change in life expectancy - Figure 10 
create_choropleth_map(change_df,"change_in_life_expectancy", the_color="orange", the_focus=[37,15],the_zoom=1.2)
# Out:
# <iframe src="about:blank" width="500" height="440"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20sr
# ...

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>It seems that Asia, Africa and South America experienced the greatest change in life expectancy.
#     </li>
#  </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>It seems that Asia, Africa and South America experienced the greatest change in life expectancy.
#     </li>
#  </div>

# %% [markdown]
# The country that experienced the greatest change in life expectancy:

# %%
#display Table 
display_df = change_df[["country","number_years_recorded",
                        "change_in_life_expectancy"]]
display_df.head(1).style.set_caption(
    "Table 12: Country with greatest life expectancy change from 1950 to 2020.").set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: top; font-size:1.00em;'
 }], overwrite=False)
# Out:
# <style type="text/css">
# #T_46b44 caption {
#   caption-side: top;
#   font-size: 1.00em;
# }
# </style>
# <table id="T_46b44">
#   <caption>Table 12: Country with greatest life expectancy change from 1950 to 2020.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46b44_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_46b44_level0_col1" class="col_heading level0 col1" >number_years_recorded</th>
#       <th id="T_46b44_level0_col2" class="col_heading level0 col2" >change_in_life_expectancy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46b44_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46b44_row0_col0" class="data row0 col0" >Cambodia</td>
#       <td id="T_46b44_row0_col1" class="data row0 col1" >59</td>
#       <td id="T_46b44_row0_col2" class="data row0 col2" >54.060000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Plot Cambodia's life expectancy over time and include the average of all countries' life expectancy worldwide.

# %%
#extract yearly data for cambodia 
output = combined_coll.aggregate([
    #filter on Cambodia
    {"$match": {"name": "Cambodia"}},
    #flatten out yearly_data
    {"$unwind": {"path": "$yearly_data"}},
    {"$project":
         {"_id": 0,
          "year": "$yearly_data.year",
          "life_expectancy": "$yearly_data.life_expectancy_dec",
          "female_life_expectancy": "$yearly_data.female_life_expectancy_dec",
          "male_life_expectancy": "$yearly_data.male_life_expectancy_dec"
          }
     },
    {"$sort": {"year": 1}},
    {"$limit": 100}
])
cambodia_df = pd.DataFrame(output)

# %%
# get average life expectancy for all countries (world wide)
average_by_year = combined_coll.aggregate([
    {"$unwind": {"path": "$yearly_data"}},
    {"$group": {"_id": "$yearly_data.year",
                "avg_life_expectancy": 
                    {"$avg": "$yearly_data.life_expectancy_dec"}
                }
     },
    {"$project":
         {"_id": 0,
          "year": "$_id",
          "avg_life_expectancy": {"$round": ["$avg_life_expectancy", 2]}
          }
     },
    {"$sort": {"year": 1}},
    {"$limit": 100}
])
average_expectancy = pd.DataFrame(average_by_year)

# %%
#Plot line graph for cambodia and world average Figure 11 

#convert to float type for graphing
cambodia_df["life_expectancy"] = cambodia_df["life_expectancy"].astype(str).astype(float)

# convert to float for plotting
average_expectancy["avg_life_expectancy"] = average_expectancy["avg_life_expectancy"].astype(str).astype(float)

plotting_df = pd.merge(cambodia_df,average_expectancy, how="left",on=["year","year"])

fig, ax = plt.subplots()
ax.plot(plotting_df["year"],plotting_df["avg_life_expectancy"], label="world_average_life_expectancy", color="black", 
         linestyle="dashdot",linewidth=2 )
ax.plot(plotting_df["year"],plotting_df["life_expectancy"] , label="Cambodia life_expectancy", linestyle="dashdot",linewidth=2 )
ax.set_ylim([0, 100])

ax.set_xlabel("year")
ax.set_ylabel("life expectancy(age)")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

txt="Figure 11. life expectancy of Cambodia and worldwide average country life expectancy."
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10)
plt.grid(axis='y', alpha=0.3)
plt.grid(axis='x', alpha=0.3)

fig.set_size_inches(7, 7)

plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>Cambodia is the country with the biggest life expectancy change worldwide (for the data we have)
#     between 1950-2020</li>
#     <li>The lowest life expectancy for Combodia happend between 1975 and 1980.
#     This seems to correspond to the same time period as the <a href="https://en.wikipedia.org/wiki/Cambodian_genocide">Cambodian genocide.</a>
#     </li>
#  </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>Cambodia is the country with the biggest life expectancy change worldwide (for the data we have)
#     between 1950-2020</li>
#     <li>The lowest life expectancy for Combodia happend between 1975 and 1980.
#     This seems to correspond to the same time period as the <a href="https://en.wikipedia.org/wiki/Cambodian_genocide">Cambodian genocide.</a>
#     </li>
#  </div>

# %% [markdown]
# ### In 2020, is there a correlation between a country's Gini Index and its life expectancy?
#
# Reuse the worldwide dataframe from the [first section](#Worldwide-in-2020,-which-countries-have-the-highest-and-lowest-life-expectancy?) rather than doing another MongoDB query.
#
# The Gini Index values (that are available in our dataset) are plotted against the country's life expectancy for the year 2020.

# %%
# %%html
# <div class="alert alert-block alert-info">
#
# The <b>Gini Index</b> is a measure of statistical dispersion intended to represent the income inequality or the wealth inequality within a nation or a social group. The Gini Index (coefficient) was developed by statistician and sociologist Corrado Gini.
# For details see <a href="https://en.wikipedia.org/wiki/Gini_coefficient">Gini Index</a>
# </div>
# Out:
# <div class="alert alert-block alert-info">
#
# The <b>Gini Index</b> is a measure of statistical dispersion intended to represent the income inequality or the wealth inequality within a nation or a social group. The Gini Index (coefficient) was developed by statistician and sociologist Corrado Gini.
# For details see <a href="https://en.wikipedia.org/wiki/Gini_coefficient">Gini Index</a>
# </div>

# %%
#graph scatter between life expectancy and the GINI Index - figure 12
life_expt_2020_df.head()

reduced_expt_2020_df = life_expt_2020_df[["country","life_expectancy","gini_value"]]
reduced_expt_2020_df = reduced_expt_2020_df.dropna()
x = reduced_expt_2020_df["gini_value"]
y = reduced_expt_2020_df["life_expectancy"]

fig, ax = plt.subplots()
ax.scatter(x, y , c="g", alpha=0.5 )
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.xlabel("gini value")
plt.ylabel("life expectancy(age)")
ax.set_ylim([0, 90])
ax.set_xlim([20, 70])

# create a fitted line
m, b = np.polyfit(x, y, deg=1)
ax.plot(x, m*x + b)

txt="Figure 12. correlation between life expectancy and Gini Index."
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10)
fig.set_size_inches(6, 6)
plt.show()


corr, _ = pearsonr(x, y)

print(f"The pearson correlation coefficient is {corr}")
# Out:
# The pearson correlation coefficient is -0.453513986915165

# %%
# %%html
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>There appears to be a negative covariance between countries average life expectancy and the countries Gini Index.</li>
#     <li>The correlation appears to be presents but would generally not be considered very strong.</li>
#     <li>Further investigation would be required (with more Gini data) to explore this potential correlation.</li>
#  </div>
# Out:
# <div class="alert alert-block alert-success">
# <b>Observations</b>:
#     <li>There appears to be a negative covariance between countries average life expectancy and the countries Gini Index.</li>
#     <li>The correlation appears to be presents but would generally not be considered very strong.</li>
#     <li>Further investigation would be required (with more Gini data) to explore this potential correlation.</li>
#  </div>

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The interesting observations for each questions are contained in the "green" boxes above. Here are some general conclusions:
#
# * The continent of Europe has consistently had a higher average country life expectancy in the last four decades
#
# * All the contients seem to have an average country life expectancy that is trending upwards.
#
# * Monaco is the overall highest life expectancy in the world in 2020

# %% [markdown]
# ## Appendix

# %% [markdown]
# ### Document formats

# %% [markdown]
# #### One Document from the "raw countries collection"

# %%
# single record from raw data 
raw_countries_data = raw_countries_coll.aggregate([
        {"$project": {"_id":0, "translations":0}},  
        {"$limit": 1}
])

for record in raw_countries_data:
    pp.pprint(record)
# Out:
# {'altSpellings': ['UY',
#                   'Oriental Republic of Uruguay',
#                   'República Oriental del Uruguay'],
#  'area': 181034.0,
#  'borders': ['ARG', 'BRA'],
#  'capital': ['Montevideo'],
#  'capitalInfo': {'latlng': [-34.85, -56.17]},
#  'car': {'side': 'right', 'signs': ['ROU']},
#  'cca2': 'UY',
#  'cca3': 'URY',
#  'ccn3': '858',
#  'cioc': 'URU',
#  'coatOfArms': {'png': 'https://mainfacts.com/media/images/coats_of_arms/uy.png',
#                 'svg': 'https://mainfacts.com/media/images/coats_of_arms/uy.svg'},
#  'continents': ['South America'],
#  'currencies': {'UYU': {'name': 'Uruguayan peso', 'symbol': '$'}},
#  'demonyms': {'eng': {'f': 'Uruguayan', 'm': 'Uruguayan'},
#               'fra': {'f': 'Uruguayenne', 'm': 'Uruguayen'}},
#  'fifa': 'URU',
#  'flag': '🇺🇾',
#  'flags': {'png': 'https://flagcdn.com/w320/uy.png',
#            'svg': 'https://flagcdn.com/uy.svg'},
#  'gini': {'2019': 39.7},
#  'idd': {'root': '+5', 'suffixes': ['98']},
# ...

# %% [markdown]
# <br><br>

# %% [markdown]
# #### One Document from the "raw census collection"

# %%
# single record from raw data 
raw_census_data = raw_census_coll.aggregate([
        {"$project": {"_id":0}},  
        {"$limit": 1}
])

for document in raw_census_data:
    pp.pprint(document)
# Out:
# {'AREA_KM2': '468',
#  'FPOP': None,
#  'GENC': 'AD',
#  'MPOP': None,
#  'NAME': 'Andorra',
#  'POP': '6176',
#  'female_life_expectancy': None,
#  'life_expectancy': None,
#  'male_life_expectancy': None,
#  'time': '1950'}

# %% [markdown]
# #### One Document from the "combined  collection"

# %%
# %%html
# <div class="alert alert-block alert-info">
# <b>NOTE</b>: In the case of the US (below), it has only one yearly data document associated. For most other countries there
#     are many documents contained in the yearly_data array.
# </div>
# Out:
# <div class="alert alert-block alert-info">
# <b>NOTE</b>: In the case of the US (below), it has only one yearly data document associated. For most other countries there
#     are many documents contained in the yearly_data array.
# </div>

# %%
# single record from raw data 
raw_combined_data = combined_coll.aggregate([
        {"$match": {"_id":"US"}},
        {"$limit": 1}
])

for document in raw_combined_data:
    pp.pprint(document)
# Out:
# {'_id': 'US',
#  'area_km2_int': 9150541,
#  'continent': 'North America',
#  'country_code': 'USA',
#  'gini_value': 41.4,
#  'name': 'United States',
#  'region': 'Americas',
#  'subregion': 'North America',
#  'yearly_data': [{'_id': ObjectId('624f030838914fe7849eb340'),
#                   'area_km2': '9150541',
#                   'country_2_code': 'US',
#                   'female_life_expectancy_dec': Decimal128('82.51'),
#                   'life_expectancy_dec': Decimal128('80.27'),
#                   'male_life_expectancy_dec': Decimal128('77.99'),
#                   'name': 'United States',
#                   'population': 332639102,
#                   'year': 2020}]}

# %%
# %%HTML
# <style>
# /* display:none  -> hide In/Out column */
# /* display:block -> show In/Out column */
# div.prompt {display:none}
# </style>
# Out:
# <style>
# /* display:none  -> hide In/Out column */
# /* display:block -> show In/Out column */
# div.prompt {display:none}
# </style>
